# %% [markdown]
# # Text Preprocessing

# %%
# %pip install spacy
# Out:
# Requirement already satisfied: spacy in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (3.8.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (2.11.2)
# Requirement already satisfied: jinja2 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (78.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/hardikprakash/Projects/topic-modelling-pipeline/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
import os

path = os.getcwd()
path = '/'.join(path.split('/')[:-1])

df = pd.read_csv(os.path.join(path, 'data/raw/airlines_reviews.csv'))

df.head()
# Out:
#                                   Title              Name Review Date  \
# 0                    Flight was amazing  Alison Soetantyo  2024-03-01
# 1  seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2          Food was plentiful and tasty             S Han  2024-02-20
# 3          “how much food was available          D Laynes  2024-02-19
# 4       “service was consistently good”         A Othman   2024-02-19
#
#               Airline Verified  \
# 0  Singapore Airlines     True
# 1  Singapore Airlines     True
# 2  Singapore Airlines     True
# 3  Singapore Airlines     True
# 4  Singapore Airlines     True
#
#                                              Reviews Type of Traveller  \
# 0    Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1    Booking an emergency exit seat still meant h...      Solo Leisure
# 2    Excellent performance on all fronts. I would...    Family Leisure
# 3   Pretty comfortable flight considering I was f...      Solo Leisure
# 4   The service was consistently good from start ...    Family Leisure
#
#      Month Flown                         Route           Class  Seat Comfort  \
# 0  December 2023          Jakarta to Singapore  Business Class             4
# 1  February 2024           Phuket to Singapore   Economy Class             5
# 2  February 2024        Siem Reap to Singapore   Economy Class             1
# 3  February 2024  Singapore to London Heathrow   Economy Class             5
# 4  February 2024       Singapore to Phnom Penh   Economy Class             5
#
#    Staff Service  Food & Beverages  Inflight Entertainment  Value For Money  \
# 0              4                 4                       4                4
# 1              3                 4                       4                1
# 2              5                 2                       1                5
# 3              5                 5                       5                5
# 4              5                 5                       5                5
#
#    Overall Rating Recommended
# 0               9         yes
# 1               3          no
# 2              10         yes
# 3              10         yes
# 4              10         yes

# %%
columns_to_keep = ['Title', 'Airline', 'Type of Traveller', 'Class', 'Route', 'Month Flown', 'Overall Rating', 'Title', 'Reviews']

df = df[columns_to_keep].dropna(subset='Reviews')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8100 entries, 0 to 8099
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              8100 non-null   object
#  1   Airline            8100 non-null   object
#  2   Type of Traveller  8100 non-null   object
#  3   Class              8100 non-null   object
#  4   Route              8100 non-null   object
#  5   Month Flown        8100 non-null   object
#  6   Overall Rating     8100 non-null   int64
#  7   Title              8100 non-null   object
#  8   Reviews            8100 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 569.7+ KB

# %%
df.head()
# Out:
#                                   Title             Airline Type of Traveller  \
# 0                    Flight was amazing  Singapore Airlines      Solo Leisure
# 1  seats on this aircraft are dreadful   Singapore Airlines      Solo Leisure
# 2          Food was plentiful and tasty  Singapore Airlines    Family Leisure
# 3          “how much food was available  Singapore Airlines      Solo Leisure
# 4       “service was consistently good”  Singapore Airlines    Family Leisure
#
#             Class                         Route    Month Flown  \
# 0  Business Class          Jakarta to Singapore  December 2023
# 1   Economy Class           Phuket to Singapore  February 2024
# 2   Economy Class        Siem Reap to Singapore  February 2024
# 3   Economy Class  Singapore to London Heathrow  February 2024
# 4   Economy Class       Singapore to Phnom Penh  February 2024
#
#    Overall Rating                                 Title  \
# 0               9                    Flight was amazing
# 1               3  seats on this aircraft are dreadful
# 2              10          Food was plentiful and tasty
# 3              10          “how much food was available
# 4              10       “service was consistently good”
#
#                                              Reviews
# 0    Flight was amazing. The crew onboard this fl...
# 1    Booking an emergency exit seat still meant h...
# 2    Excellent performance on all fronts. I would...
# 3   Pretty comfortable flight considering I was f...
# 4   The service was consistently good from start ...

# %%
# !python -m spacy download en_core_web_sm

# %%
import re
import spacy

nlp = spacy.load('en_core_web_sm')
tokenizer = nlp.tokenizer



def clean_reviews(review, tokenizer):
    review = re.sub(r'[^a-zA-Z0-9\s]', '', review.lower())
    doc = nlp(review)
    return " ".join([token.lemma_ for token in doc if not token.is_stop])

# %%
from tqdm import tqdm
tqdm.pandas()

df['Cleaned Reviews'] = df['Reviews'].progress_apply(clean_reviews, tokenizer=tokenizer)
df.head()
# Out:
# 100%|██████████| 8100/8100 [02:54<00:00, 46.29it/s]
#                                   Title             Airline Type of Traveller  \
# 0                    Flight was amazing  Singapore Airlines      Solo Leisure
# 1  seats on this aircraft are dreadful   Singapore Airlines      Solo Leisure
# 2          Food was plentiful and tasty  Singapore Airlines    Family Leisure
# 3          “how much food was available  Singapore Airlines      Solo Leisure
# 4       “service was consistently good”  Singapore Airlines    Family Leisure
#
#             Class                         Route    Month Flown  \
# 0  Business Class          Jakarta to Singapore  December 2023
# 1   Economy Class           Phuket to Singapore  February 2024
# 2   Economy Class        Siem Reap to Singapore  February 2024
# 3   Economy Class  Singapore to London Heathrow  February 2024
# 4   Economy Class       Singapore to Phnom Penh  February 2024
#
#    Overall Rating                                 Title  \
# 0               9                    Flight was amazing
# 1               3  seats on this aircraft are dreadful
# 2              10          Food was plentiful and tasty
# 3              10          “how much food was available
# 4              10       “service was consistently good”
#
#                                              Reviews  \
# 0    Flight was amazing. The crew onboard this fl...
# 1    Booking an emergency exit seat still meant h...
# 2    Excellent performance on all fronts. I would...
# 3   Pretty comfortable flight considering I was f...
# 4   The service was consistently good from start ...
#
#                                      Cleaned Reviews
# 0     flight amazing crew onboard flight welcomin...
# 1     book emergency exit seat mean huge discomfo...
# 2     excellent performance front definitely choo...
# 3    pretty comfortable flight consider fly econo...
# 4    service consistently good start finish cabin...

# %%
path = os.getcwd()
path = '/'.join(path.split('/')[:-1])

os.makedirs(os.path.join(path, 'data/processed/'), exist_ok=True)
df.to_csv(os.path.join(path, 'data/processed/reviews.csv'), index=False)

# %% [markdown]
# ## EDA
